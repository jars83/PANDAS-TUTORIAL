# %%
import pandas as pd
import requests
import json

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 500)

# %%
b=pd.read_csv("2021_key_metrics_quarter_bulk.csv")

# %%
r = requests.get('https://financialmodelingprep.com/api/v3/available-traded/list?apikey=26de94bf24a57d24a20c9622439509d4')

# %%
a=r.json()

# %%
type(a)
# Out:
# list

# %%
b.set_index('symbol', inplace=True)

# %%
df3 = pd.merge(b, fdata, left_index=True, right_index=True)

# %%
data=pd.DataFrame(a)

# %%
df3.loc["AMD"]
# Out:
#               date period  revenuePerShare  netIncomePerShare  operatingCashFlowPerShare  freeCashFlowPerShare  cashPerShare  bookValuePerShare  tangibleBookValuePerShare  shareholdersEquityPerShare  interestDebtPerShare     marketCap  enterpriseValue    peRatio  priceToSalesRatio   pocfratio   pfcfRatio    pbRatio   ptbRatio  evToSales  enterpriseValueOverEBITDA  evToOperatingCashFlow  earningsYield  freeCashFlowYield  debtToEquity  debtToAssets  netDebtToEBITDA  currentRatio  \
# symbol
# AMD     2021-09-25     Q3         3.552718           0.760297                   0.699341              0.629325      2.971993           5.878089                   5.472817                    5.878089              0.485173  1.284412e+11     1.265832e+11  34.789057          29.780014  151.285277  168.116754  17.999047  17.999047  29.349223                 112.618505             149.096820       0.007186           0.005948      0.037836      0.360172        -1.653025      2.241302
# ...

# %%
fdata=data[(data['exchangeShortName']=="NYSE") | ( data['exchangeShortName']=="NASDAQ") | ( data['exchangeShortName']=="AMEX") ]

# %%
fdata.loc["XPEV"]
# Out:
# exchange             New York Stock Exchange
# exchangeShortName                       NYSE
# name                              XPeng Inc.
# price                                  44.47
# Name: XPEV, dtype: object

# %%
fdata.set_index('symbol', inplace=True)
